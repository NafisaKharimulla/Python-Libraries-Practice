# %%
import matplotlib.pyplot as plt
Datas = {
    "hours_studied": [5, 10, 25, 20, 15],
    "score": [50, 60, 70, 80, 90]
}

plt.scatter(Datas["hours_studied"], Datas["score"])
plt.show()

# %% [markdown]
# Based on the plotting i can say there is positive correlation
