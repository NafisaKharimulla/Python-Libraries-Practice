# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
sales = np.random.randint(100, 500, (7, 24))
df = pd.DataFrame(sales)
df_sorted = pd.DataFrame(np.sort(df.values))
plt.plot(df_sorted)
plt.xlabel("Hour")
plt.ylabel("Sales")
plt.show()
